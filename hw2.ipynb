# %% [markdown]
# ## Домашнее задание №2
# ### Выполнили: Алексеев Антон, Булатов Артур, Корнеева Елизавета ИАД1

# %% [markdown]
# #### Краткая постановка задачи и формулировка задания:

# %% [markdown]
# Домашнее задание заключается в предсказании роста цен акции компании Газпром по новостям о компании.
# Для этого, первым делом, нужно предобработать входные данные, затем построить модель, затем нужно попробовать усовершенствовать свои предсказания любыми законными способами

# %% [markdown]
# #### Описание используемых инструментов:

# %% [markdown]
# pandas — программная библиотека на языке Python для обработки и анализа данных. Pandas предоставляет специальные структуры данных и операции для манипулирования числовыми таблицами и временными рядами.
# pymorphy2 - морфологический анализатор для русского языка, написанный на языке Python и использующий словари из OpenCorpora. Он работает под Python 2.6, 2.7, 3.2 и 3.3 и распространяется по лицензии MIT.

# %% [markdown]
# #### Краткий план работы программы:

# %% [markdown]
#    - Часть первая "Вводная"
#         - Предобработка текста – убираем пунктуацию, стоп-слова и приводим к начальной форме.
#    - Часть вторая "Классификационная"
#         - Baseline tf-idf + MultinomialNB
#         - Подбор гиперпараметров GridSearchCV
#    - Часть третья "Творческая "
#         - Пробуем оставить только существительные
#         - Пробуем оставить только существительные + глаголы
#         - Пробуем оставить только слова из топиков LDA

# %% [markdown]
# Более подробно каждый шаг расписан в виде комментариев к коду

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from nltk.corpus import stopwords
from string import punctuation
import re
import pymorphy2
from numpy import corrcoef
from datetime import datetime
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder  
from sklearn import metrics
import nltk
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation as lda

import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ## Часть 1. Вводная [3 балла]
#
# Проведите предобработку текстов: если считаете нужным, выполните токенизацию, приведение к нижнему регистру, лемматизацию и/или стемминг. Ответьте на следующие вопросы:
# * Есть ли корреляция между средней длинной текста за день и ценой закрытия?
# * Есть ли корреляция между количеством упоминаний Алексея Миллера  и ценой закрытия? Учтите разные варианты написания имени.
# * Упоминаний какого газопровода в статьях больше:
#     * "северный поток"
#     * "турецкий поток"?
# * Кого упоминают чаще:
#     * Алексея Миллера
#     * Владимира Путина?
# * О каких санкциях пишут в статьях?

# %%
texts = pd.read_csv('texts.csv')
texts.head()
# Out:
#          date                                               text
# 0  09.11.2017  Компания рассчитывает на решение по газовому с...
# 1  08.11.2017   Как и предполагал “Ъ”, «Газпром», воспользова...
# 2  01.11.2017   Новая редакция американских санкций ставит по...
# 3  30.10.2017   Как стало известно “Ъ”, известный на рынке ри...
# 4  23.10.2017   НОВАТЭК, который через пять лет собирается за...

# %%
pr_all = pd.read_csv('gazprom_prices.csv', sep=';')
pr_all.head(5)
# Out:
#          Date       Open ClosingPrice  DailyHigh   DailyLow  VolumePcs
# 0  08.12.2017  133,43000    132,60000  133,90000  132,00000   16037970
# 1  07.12.2017  133,70000    133,02000  133,87000  132,81000   18198430
# 2  06.12.2017  133,33000    134,00000  134,29000  132,91000   14641730
# 3  05.12.2017  133,48000    133,65000  133,99000  132,78000   12684800
# 4  04.12.2017  133,01000    133,77000  134,00000  131,93000   17818980

# %%
texts.rename(columns={'text': 'text_original'}, inplace=True)
texts['text'] = texts['text_original']

# предобработка текста
for i in tqdm(range(len(texts['text_original'][:]))):
    # убираем стоп-слова
    s = ' '.join([word for word in texts['text_original'][i].split() if word not in stopwords.words('russian')])
    # убираем пунктуацию
    s = ''.join(c for c in s if c not in punctuation)

    # приводим слова в начальную форму
    pymorph = pymorphy2.MorphAnalyzer()
    words = []
    for word in s.split():
        word = pymorph.parse(word)[0].normal_form
        words.append(word)
    texts['text'][i] = ' '.join(words)
# Out:
# 100%|██████████| 1203/1203 [04:27<00:00,  4.51it/s]

# %%
texts.head()
# Out:
#          date                                      text_original  \
# 0  09.11.2017  Компания рассчитывает на решение по газовому с...
# 1  08.11.2017   Как и предполагал “Ъ”, «Газпром», воспользова...
# 2  01.11.2017   Новая редакция американских санкций ставит по...
# 3  30.10.2017   Как стало известно “Ъ”, известный на рынке ри...
# 4  23.10.2017   НОВАТЭК, который через пять лет собирается за...
#
#                                                 text
# 0  компания рассчитывать решение газовый спор укр...
# 1  как предполагать “ъ” «газпром» воспользоваться...
# 2  новый редакция американский санкция ставить уг...
# 3  как стать известно “ъ” известный рынок рискмен...
# 4  новатэк который пять год собираться запустить ...

# %%
# переводим цену закрытия из строки во float для работы с числами
pr_all['ClosingPrice'] = [float(i.replace(',', '.')) for i in pr_all['ClosingPrice'][:]]
pr_all.head()
# Out:
#          Date       Open  ClosingPrice  DailyHigh   DailyLow  VolumePcs
# 0  08.12.2017  133,43000        132.60  133,90000  132,00000   16037970
# 1  07.12.2017  133,70000        133.02  133,87000  132,81000   18198430
# 2  06.12.2017  133,33000        134.00  134,29000  132,91000   14641730
# 3  05.12.2017  133,48000        133.65  133,99000  132,78000   12684800
# 4  04.12.2017  133,01000        133.77  134,00000  131,93000   17818980

# %%
# соединяем данные по дате
texts.rename(columns={'date': 'Date'}, inplace=True)
result = pd.merge(texts, pr_all, on='Date')

# %% [markdown]
# ### Есть ли корреляция между средней длинной текста за день и ценой закрытия?

# %%
from numpy import corrcoef
coef = corrcoef(result['ClosingPrice'][:], [len(t) for t in result['text'][:]])[0, 1]
print("Коеффициент корреляции Пирсона между ценой закрытия и длинной текста – ", coef)
# Out:
# Коеффициент корреляции Пирсона между ценой закрытия и длинной текста –  0.01370484309179625

# %% [markdown]
# Судя по коэффициенту корреляции - цена закрытия не зависит от средней длины текста за день

# %% [markdown]
# ### Есть ли корреляция между количеством упоминаний Алексея Миллера и ценой закрытия?

# %%
pattern_miller = re.compile(r'(Миллер)', re.IGNORECASE)
res = []
for i in range(len(result['text'][:])):
    search_str = texts['text'][i]
    res = re.findall(pattern_miller, search_str)
    res.append(len(res))

    
coef = corrcoef(result['ClosingPrice'][:], [len(re.findall(pattern_miller, t)) for t in result['text'][:]])[0, 1]
print("Коеффициент корреляции Пирсона между ценой закрытия и упоминаниями Миллера – ", coef)
# Out:
# Коеффициент корреляции Пирсона между ценой закрытия и упоминаниями Миллера –  0.010635076467578003

# %% [markdown]
# Судя по коэффициенту корреляции - цена закрытия не зависит от количества упоминаний Миллера

# %% [markdown]
# ### Упоминаний какого газопровода в статьях больше:
#  - "северный поток"
#  - "турецкий поток"?

# %%
pattern1 = re.compile(r'(северный поток)', re.IGNORECASE)
pattern2 = re.compile(r'(турецкий поток)', re.IGNORECASE)

res1, res2 = 0, 0

for i in range(len(result['text'][:])):
    search_str = texts['text'][i]
    res = re.findall(pattern1, search_str)
    res1 += len(res)
    res = re.findall(pattern2, search_str)
    res2 += len(res)
    
print("Северный поток - ", res1)
print("Турецкий поток - ", res2)
# Out:
# Северный поток -  15
# Турецкий поток -  39

# %% [markdown]
# Турецкий поток упоминается более чем в два раза чаще, чем северный поток

# %% [markdown]
# ### Кого упоминают чаще:
#  - Алексея Миллера
#  - Владимира Путина?

# %%
pattern_miller = re.compile(r'(Миллер)', re.IGNORECASE)
pattern_putin = re.compile(r'(Путин)', re.IGNORECASE)

res_miller, res_putin = 0, 0

for i in range(len(result['text'][:])):
    search_str = texts['text'][i]
    res = re.findall(pattern_miller, search_str)
    res_miller += len(res)
    res = re.findall(pattern_putin, search_str)
    res_putin += len(res)
    
print("Упоминания Миллера - ", res_miller)
print("Упоминания Путина - ", res_putin)
# Out:
# Упоминания Миллера -  147
# Упоминания Путина -  72

# %% [markdown]
# Миллер упоминается более чем в два раза чаще, чем Путин

# %% [markdown]
# ### О каких санкциях пишут в статьях?

# %%
all_tokens = []
for i in tqdm(range(len(texts['text'][:]))):
    tokens = nltk.word_tokenize(texts['text'][i])
    text = nltk.Text(tokens)
    all_tokens.extend(text)
text = nltk.Text(all_tokens)   

text.concordance('санкция')
# Out:
# 100%|██████████| 1203/1203 [00:01<00:00, 1147.36it/s]
# Displaying 25 of 67 matches:
# нополия новый редакция американский санкция ставить угроза зарубежный нефтяной
#  ” участок интересоваться shell изз санкция иностранец 2014 год шельф россия по
#  ” участок интересоваться shell изз санкция иностранец 2014 год шельф россия по
# й компания рф наблюдаться число изз санкция эксперт полагать сила опыт организа
# й компания рф наблюдаться число изз санкция эксперт полагать сила опыт организа
# изингодатель почувствовать западный санкция “ ъ ” рассказать гендиректор « газп
# рдить правомерность ввести совет ес санкция отношение « роснефти » брюссель зап
# ение дело недовольный грозить банка санкция территория украина два крупный росс
# ение дело недовольный грозить банка санкция территория украина казахстан подтве
# южнокиринский месторождение попасть санкция по мнение эксперт пока речь идти по
# ение направление серьёзно осложнять санкция сша украина подать иск киевский суд
# ка повышение ликвидность находиться санкция банка если полторадва год убыток пр
# нс 65 собственный акция газпром фон санкция начинать предпринимать реальный дей
# рудничество заморозить изз западный санкция против банка владивосток спг отменн
# вать спешить при падение цена нефть санкция работа шельф сворачивать госкомпани
# страховка случай введение очередной санкция перевод расчёт экспорт российский н
# з газпром который сей пора западный санкция затрагивать впервые попасть удар сш
# вести западный страна экономический санкция против россия оао газпром начало 20
# ежний стремиться связывать крым изз санкция репутационный риск вчера выясниться
# оект российский тэк момент введение санкция против рф а получение технология ин
# оект российский тэк момент введение санкция против рф а получение технология ин
# ь эмитент находиться антироссийский санкция конвертировать доллар занимать кото
# б газпромбанк подпасть персональный санкция рнкб смп банк банк « россия » также
# о хотеть подвергать монополия риска санкция сторона ес сша переговоры еврокомис
# я крайне маленький газпром несмотря санкция проблема привлечение финансирование

# %% [markdown]
# ## Часть 2. Классификационная [3 балла]
# Вам предстоит решить следующую задачу: по текстам новостей за день определить, вырастет или понизится цена закрытия.
# Для этого:
# * бинаризуйте признак "цена закрытия":  новый признак ClosingPrice_bin равен 1, если по сравнению со вчера цена не упала, и 0 – в обратном случаея;
# * составьте обучающее и тестовое множество: данные до начала 2016 года используются для обучения, данные с 2016 года и позже – для тестирования.
#
# Таким образом, в каждлый момент времени мы знаем:
# * ClosingPrice_bin – бинарый целевой признак
# * слова из статей, опубликованных в этот день – объясняющие признаки
#
# В этой части задания вам нужно сделать baseline алгоритм и попытаться его улучшить в следующей части.
#
# Используйте любой известный вам алгоритм классификации текстов для того, Используйте $tf-idf$ преобразование, сингулярное разложение, нормировку признакого пространства и любые другие техники обработки данных, которые вы считаете нужным. Используйте accuracy и F-measure для оценки качества классификации. Покажите, как  $tf-idf$ преобразование или сингулярное разложение или любая другая использованная вами техника влияет на качество классификации.
# Если у выбранного вами алгоритма есть гиперпараметры (например, $\alpha$ в преобразовании Лапласа для метода наивного Байеса), покажите, как изменение гиперпараметра влияет на качество классификации.

# %%
# добавляем новый столбец 0-1 понижение-повышение цены
new_column = [] 
for i in range(len(pr_all['ClosingPrice']) - 1): 
    new_column.append(0 if pr_all['ClosingPrice'][i] < pr_all['ClosingPrice'][i + 1] else 1) 
new_column.append(0) 

pr_all['ClosingPrice_bin'] = new_column

# %%
# соединяем с нашими текстами
df = pd.merge(result[['Date', 'text', 'text_original']], pr_all[['Date', 'ClosingPrice_bin']], on='Date')
df.head()
# Out:
#          Date                                               text  \
# 0  09.11.2017  компания рассчитывать решение газовый спор укр...
# 1  08.11.2017  как предполагать “ъ” «газпром» воспользоваться...
# 2  01.11.2017  новый редакция американский санкция ставить уг...
# 3  30.10.2017  как стать известно “ъ” известный рынок рискмен...
# 4  23.10.2017  новатэк который пять год собираться запустить ...
#
#                                        text_original  ClosingPrice_bin
# 0  Компания рассчитывает на решение по газовому с...                 0
# 1   Как и предполагал “Ъ”, «Газпром», воспользова...                 1
# 2   Новая редакция американских санкций ставит по...                 1
# 3   Как стало известно “Ъ”, известный на рынке ри...                 1
# 4   НОВАТЭК, который через пять лет собирается за...                 1

# %%
date_format = "%d.%m.%Y"

for i in tqdm(range(len(df['Date']))):
    date = datetime.strptime(df['Date'][i], date_format)
    df['Date'][i] = date
df.rename(columns={'ClosingPrice_bin': 'target'}, inplace=True)
df.head()
# Out:
# 100%|██████████| 1159/1159 [01:17<00:00, 14.94it/s]
#                   Date                                               text  \
# 0  2017-11-09 00:00:00  компания рассчитывать решение газовый спор укр...
# 1  2017-11-08 00:00:00  как предполагать “ъ” «газпром» воспользоваться...
# 2  2017-11-01 00:00:00  новый редакция американский санкция ставить уг...
# 3  2017-10-30 00:00:00  как стать известно “ъ” известный рынок рискмен...
# 4  2017-10-23 00:00:00  новатэк который пять год собираться запустить ...
#
#                                        text_original  target
# 0  Компания рассчитывает на решение по газовому с...       0
# 1   Как и предполагал “Ъ”, «Газпром», воспользова...       1
# 2   Новая редакция американских санкций ставит по...       1
# 3   Как стало известно “Ъ”, известный на рынке ри...       1
# 4   НОВАТЭК, который через пять лет собирается за...       1

# %%
# делим на трейн/тест
df_train, df_test = df[df['Date'] < datetime(2016, 1, 1)], df[df['Date'] >= datetime(2016, 1, 1)]
print('train size %d, test size %d' % (df_train.shape[0], df_test.shape[0]))
# Out:
# train size 901, test size 258

# %%
df_train.index = range(len(df_train.index))
df_test.index = range(len(df_test.index))

# %% [markdown]
# ### word tf-idf + MultinomialNB

# %%
# build binary feature matrix from BoW model
vec = TfidfVectorizer(lowercase=True, analyzer='word', ngram_range=(1,1), norm=None, use_idf=False, binary=True)
X = vec.fit_transform(df_train.text)
print('feature matrix shape', X.shape)

# encode class labels
label_enc = LabelEncoder().fit(df_train.target)
y_train = label_enc.transform(df_train.target)

# fit our prediction model
model = MultinomialNB(alpha=0.5)
model.fit(X, y_train)
print('train f1_score', metrics.f1_score(y_train, model.predict(X)))
print('train accuracy', metrics.accuracy_score(y_train, model.predict(X)))

# perfomance on test dataset
X_test = vec.transform(df_test.text)
y_pred = model.predict(X_test)
y_test = label_enc.transform(df_test.target)
print('test f1_score', metrics.f1_score(y_test, model.predict(X_test)))
print('test accuracy', metrics.accuracy_score(y_test, model.predict(X_test)))
# Out:
# feature matrix shape (901, 7736)
# train f1_score 0.9785794813979707
# train accuracy 0.978912319644839
# test f1_score 0.415686274509804
# test accuracy 0.42248062015503873

# %% [markdown]
# ### word tf-idf + MultinomialNB + GridSearchCV alpha

# %%
# build binary feature matrix from BoW model
vec = TfidfVectorizer(lowercase=True, analyzer='word', ngram_range=(2,4), norm=None, use_idf=False, binary=True)
X = vec.fit_transform(df_train.text)
print('feature matrix shape', X.shape)

# encode class labels
label_enc = LabelEncoder().fit(df_train.target)
y_train = label_enc.transform(df_train.target)

grid = GridSearchCV(MultinomialNB(), # our model 
                    param_grid={'alpha': np.linspace(-1.0, 2.0, 31)})
 
grid.fit(X, y_train)
print('best params', grid.best_params_)
print('best estimator', grid.best_score_)
model = grid.best_estimator_


# fit our prediction model
# model = MultinomialNB(alpha=0.9)
model.fit(X, y_train)
print('train f1_score', metrics.f1_score(y_train, model.predict(X)))
print('train accuracy', metrics.accuracy_score(y_train, model.predict(X)))

# perfomance on test dataset
X_test = vec.transform(df_test.text)
y_pred = model.predict(X_test)
y_test = label_enc.transform(df_test.target)
print('test f1_score', metrics.f1_score(y_test, model.predict(X_test)))
print('test accuracy', metrics.accuracy_score(y_test, model.predict(X_test)))
# Out:
# feature matrix shape (901, 167792)
# best params {'alpha': 0.10000000000000009}
# best estimator 0.5405105438401776
# train f1_score 1.0
# train accuracy 1.0
# test f1_score 0.502092050209205
# test accuracy 0.5387596899224806

# %% [markdown]
# ### char tf-idf  + LogisticRegression + GridSearchCV (C, penalty)

# %%
SEED = 2018

# build feature matrix from 3-grams
# with l2-normalization and smoothed idf
vec = TfidfVectorizer(lowercase=True, analyzer='char', ngram_range=(3,3), norm='l2', use_idf=True, smooth_idf=True)
X = vec.fit_transform(df_train.text)
print('feature matrix shape', X.shape)

# Logistic Regression classifier has several hyperparams
grid = GridSearchCV(LogisticRegression(random_state=SEED), # our model 
                   param_grid={'C': np.logspace(0,5,10),
                               'penalty': ['l1', 'l2']}, 
                    scoring='f1', # our perfomance measure 
                    n_jobs=-1, # multithread 
                    cv=5, # 5-fold stratified cross-validation 
                    verbose=True, return_train_score=True)

grid.fit(X, y_train)
print('best params', grid.best_params_)
print('best estimator', grid.best_score_)
model = grid.best_estimator_

# grid.best_estimator_ is already fitted on whole train dataset
print('train', metrics.f1_score(y_train, model.predict(X)))

# perfomance on test dataset
X_test = vec.transform(df_test.text)
y_pred = model.predict(X_test)
print('test', metrics.f1_score(y_test, model.predict(X_test)))
# Out:
# feature matrix shape (901, 10806)
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    6.7s finished
# best params {'C': 12.91549665014884, 'penalty': 'l1'}
# best estimator 0.5194099456597111
# train 0.9977678571428571
# test 0.49420849420849416

# %% [markdown]
# ### char tf-idf  + exclude 3-grams appeared in less then 10 texts + LogisticRegression + GridSearchCV (C, penalty)

# %%
# baseline 3

# build feature matrix from 3-grams
vec = TfidfVectorizer(lowercase=True, analyzer='char', ngram_range=(3,3), 
                      min_df=10, # exclude 3-grams appeared in less then 10 texts. 
                      use_idf=True)
X = vec.fit_transform(df_train.text)
print('feature matrix shape', X.shape)

# optimize  hyperparams
grid = GridSearchCV(LogisticRegression(random_state=SEED), 
                   param_grid={'C': np.logspace(0,5,10), 
                               'penalty': ['l1', 'l2']}, 
                    scoring='f1', n_jobs=-1, cv=5, verbose=True, return_train_score=True)

grid.fit(X, y_train)
print(grid.best_params_)
print(grid.best_score_)
model = grid.best_estimator_
print('train', metrics.f1_score(y_train, model.predict(X)))

X_test = vec.transform(df_test.text)
y_pred = model.predict(X_test)
print('test', metrics.f1_score(y_test, model.predict(X_test)))
# Out:
# feature matrix shape (901, 3848)
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    5.7s finished
# {'C': 3.5938136638046276, 'penalty': 'l1'}
# 0.5205123462060199
# train 0.824188129899216
# test 0.46268656716417916

# %% [markdown]
# ## accuracy = 0.5387 получилось максимум на word tf-idf + MultinomialNB + GridSearchCV alpha

# %% [markdown]
# ## Часть 3. Творческая [4 балла]
# Придумайте и попытайтесь сделать еще что-нибудь, чтобы улучшить качество классификации.
# Направления развития:
# * Морфологический признаки:
#     * использовать в качестве признаков только существительные или только именованные сущности;
# * Модели скрытых тем:
#     * использовать в качестве признаков скрытые темы;
#     * использовать в качестве признаков динамические скрытые темы
#     пример тут: (https://github.com/RaRe-Technologies/gensim/blob/develop/docs/notebooks/dtm_example.ipynb)
# * Синтаксические признаки:
#     * использовать SOV-тройки в качестве признаков
#     * кластеризовать SOV-тройки по усредненным эмбеддингам  (обученные word2vec модели можно скачать отсюда: (http://rusvectores.org/ru/models/ или https://github.com/facebookresearch/fastText/blob/master/pretrained-vectors.md) и использовать только центроиды кластеров в качестве признаков
# * что-нибудь еще

# %%
df.head()
# Out:
#                   Date                                               text  \
# 0  2017-11-09 00:00:00  компания рассчитывать решение газовый спор укр...
# 1  2017-11-08 00:00:00  как предполагать “ъ” «газпром» воспользоваться...
# 2  2017-11-01 00:00:00  новый редакция американский санкция ставить уг...
# 3  2017-10-30 00:00:00  как стать известно “ъ” известный рынок рискмен...
# 4  2017-10-23 00:00:00  новатэк который пять год собираться запустить ...
#
#                                        text_original  target
# 0  Компания рассчитывает на решение по газовому с...       0
# 1   Как и предполагал “Ъ”, «Газпром», воспользова...       1
# 2   Новая редакция американских санкций ставит по...       1
# 3   Как стало известно “Ъ”, известный на рынке ри...       1
# 4   НОВАТЭК, который через пять лет собирается за...       1

# %% [markdown]
# ### Оставим только существительные

# %%
morph = pymorphy2.MorphAnalyzer()

df['text_nouns'] = df['text']
for i in tqdm(range(len(df['text']))):
    sent = df['text'][i]
    res = []
    for word in sent.split():
        if morph.parse(word)[0].tag.POS == 'NOUN':
            res.append(word)
    df['text_nouns'][i] = ' '.join(res)
# Out:
# 100%|██████████| 1159/1159 [01:59<00:00,  9.71it/s]

# %%
df.head()
# Out:
#                   Date                                               text  \
# 0  2017-11-09 00:00:00  компания рассчитывать решение газовый спор укр...
# 1  2017-11-08 00:00:00  как предполагать “ъ” «газпром» воспользоваться...
# 2  2017-11-01 00:00:00  новый редакция американский санкция ставить уг...
# 3  2017-10-30 00:00:00  как стать известно “ъ” известный рынок рискмен...
# 4  2017-10-23 00:00:00  новатэк который пять год собираться запустить ...
#
#                                        text_original  target  \
# 0  Компания рассчитывает на решение по газовому с...       0
# 1   Как и предполагал “Ъ”, «Газпром», воспользова...       1
# 2   Новая редакция американских санкций ставит по...       1
# 3   Как стало известно “Ъ”, известный на рынке ри...       1
# 4   НОВАТЭК, который через пять лет собирается за...       1
#
#                                           text_nouns
# 0  компания решение украина конец декабрь решение...
# 1  жалоба партнёр налогообложение проект рф сниже...
# 2  редакция санкция угроза проект компания гражда...
# 3  рынок рискменеджер itспециалист вадим кулик ра...
# 4  новатэк год камчатка терминал проблема обеспеч...

# %%
df_train, df_test = df[df['Date'] < datetime(2016, 1, 1)], df[df['Date'] >= datetime(2016, 1, 1)]
print('train size %d, test size %d' % (df_train.shape[0], df_test.shape[0]))
# Out:
# train size 901, test size 258

# %%
# build binary feature matrix from BoW model
vec = TfidfVectorizer(lowercase=True, analyzer='word', ngram_range=(2,4), norm=None, use_idf=False, binary=True)
X = vec.fit_transform(df_train.text_nouns)
print('feature matrix shape', X.shape)

# encode class labels
label_enc = LabelEncoder().fit(df_train.target)
y_train = label_enc.transform(df_train.target)

grid = GridSearchCV(MultinomialNB(), # our model 
                    param_grid={'alpha': np.linspace(-1.0, 2.0, 31)})
 
grid.fit(X, y_train)
print('best params', grid.best_params_)
print('best estimator', grid.best_score_)
model = grid.best_estimator_


# fit our prediction model
model.fit(X, y_train)
print('train f1_score', metrics.f1_score(y_train, model.predict(X)))
print('train accuracy', metrics.accuracy_score(y_train, model.predict(X)))

# perfomance on test dataset
X_test = vec.transform(df_test.text_nouns)
y_pred = model.predict(X_test)
y_test = label_enc.transform(df_test.target)
print('test f1_score', metrics.f1_score(y_test, model.predict(X_test)))
print('test accuracy', metrics.accuracy_score(y_test, model.predict(X_test)))
# Out:
# feature matrix shape (901, 89180)
# best params {'alpha': 0.10000000000000009}
# best estimator 0.5194228634850167
# train f1_score 1.0
# train accuracy 1.0
# test f1_score 0.4645669291338583
# test accuracy 0.4728682170542636

# %% [markdown]
# ### Оставим только существительные и глаголы

# %%
df['text_nouns_verbs'] = df['text']
for i in tqdm(range(len(df['text']))):
    sent = df['text'][i]
    res = []
    for word in sent.split():
        if (morph.parse(word)[0].tag.POS == 'NOUN') or (morph.parse(word)[0].tag.POS == 'VERB'):
            res.append(word)
    df['text_nouns_verbs'][i] = ' '.join(res)
# Out:
# 100%|██████████| 1159/1159 [02:07<00:00,  9.11it/s]

# %%
df.head()
# Out:
#                   Date                                               text  \
# 0  2017-11-09 00:00:00  компания рассчитывать решение газовый спор укр...
# 1  2017-11-08 00:00:00  как предполагать “ъ” «газпром» воспользоваться...
# 2  2017-11-01 00:00:00  новый редакция американский санкция ставить уг...
# 3  2017-10-30 00:00:00  как стать известно “ъ” известный рынок рискмен...
# 4  2017-10-23 00:00:00  новатэк который пять год собираться запустить ...
#
#                                        text_original  target  \
# 0  Компания рассчитывает на решение по газовому с...       0
# 1   Как и предполагал “Ъ”, «Газпром», воспользова...       1
# 2   Новая редакция американских санкций ставит по...       1
# 3   Как стало известно “Ъ”, известный на рынке ри...       1
# 4   НОВАТЭК, который через пять лет собирается за...       1
#
#                                           text_nouns  \
# 0  компания решение украина конец декабрь решение...
# 1  жалоба партнёр налогообложение проект рф сниже...
# 2  редакция санкция угроза проект компания гражда...
# 3  рынок рискменеджер itспециалист вадим кулик ра...
# 4  новатэк год камчатка терминал проблема обеспеч...
#
#                                     text_nouns_verbs
# 0  компания решение украина конец декабрь решение...
# 1  жалоба партнёр налогообложение проект рф сниже...
# 2  редакция санкция угроза проект компания гражда...
# 3  рынок рискменеджер itспециалист вадим кулик ра...
# 4  новатэк год камчатка терминал проблема обеспеч...

# %%
df_train, df_test = df[df['Date'] < datetime(2016, 1, 1)], df[df['Date'] >= datetime(2016, 1, 1)]
print('train size %d, test size %d' % (df_train.shape[0], df_test.shape[0]))
# Out:
# train size 901, test size 258

# %%
# build binary feature matrix from BoW model
vec = TfidfVectorizer(lowercase=True, analyzer='word', ngram_range=(2,4), norm=None, use_idf=False, binary=True)
X = vec.fit_transform(df_train.text_nouns_verbs)
print('feature matrix shape', X.shape)

# encode class labels
label_enc = LabelEncoder().fit(df_train.target)
y_train = label_enc.transform(df_train.target)

grid = GridSearchCV(MultinomialNB(), # our model 
                    param_grid={'alpha': np.linspace(-1.0, 2.0, 31)})
 
grid.fit(X, y_train)
print('best params', grid.best_params_)
print('best estimator', grid.best_score_)
model = grid.best_estimator_

# fit our prediction model
model.fit(X, y_train)
print('train f1_score', metrics.f1_score(y_train, model.predict(X)))
print('train accuracy', metrics.accuracy_score(y_train, model.predict(X)))

# perfomance on test dataset
X_test = vec.transform(df_test.text_nouns_verbs)
y_pred = model.predict(X_test)
y_test = label_enc.transform(df_test.target)
print('test f1_score', metrics.f1_score(y_test, model.predict(X_test)))
print('test accuracy', metrics.accuracy_score(y_test, model.predict(X_test)))
# Out:
# feature matrix shape (901, 89711)
# best params {'alpha': 0.10000000000000009}
# best estimator 0.5049944506104328
# train f1_score 1.0
# train accuracy 1.0
# test f1_score 0.45849802371541504
# test accuracy 0.4689922480620155

# %% [markdown]
# ### Оставим только те слова, которые входят в топики LDA

# %%
all_text = []
for i in tqdm(range(len(df['text'][:]))):
    sent = df['text'][i]
    all_text.append(sent)
# Out:
# 100%|██████████| 1159/1159 [00:00<00:00, 37069.05it/s]

# %%
cv = CountVectorizer(max_features = 1000)
transformed_dataset = cv.fit_transform(all_text)
transformed_dataset
# Out:
# <1159x1000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 47698 stored elements in Compressed Sparse Row format>

# %%
tf_feature_names = cv.get_feature_names()
assert len(tf_feature_names) == 1000
tf_feature_names
# Out:
# ['10',
#  '100',
#  '1000',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16',
#  '17',
#  '18',
#  '20',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2020',
#  '22',
#  '24',
#  '25',
#  '27',
#  '30',
#  '40',
#  '400',
#  '49',
#  '50',
#  '500',
#  '70',
#  '75',
#  'ag',
#  'cnpc',
#  'dujos',
#  'energy',
#  'eni',
#  'eon',
#  'gas',
#  'gazprom',
#  'germania',
#  'lietuvos',
#  'nis',
#  'nord',
#  'opal',
#  'reuters',
#  'shell',
#  'south',
#  'statoil',
#  'stream',
#  'total',
#  'wintershall',
#  'август',
#  'автономный',
#  'агентство',
#  'актив',
#  'активно',
#  'активный',
#  'акционер',
#  'акция',
#  'александр',
#  'алексей',
#  'альянс',
#  'американский',
#  'аналитик',
#  'аналитика',
#  'аналогичный',
#  'андрей',
#  'антимонопольный',
#  'апрель',
#  'арбитраж',
#  'арбитражный',
#  'аукцион',
#  'аэропорт',
#  'база',
#  'балтийский',
#  'банк',
#  'банка',
#  'банковский',
#  'белоруссия',
#  'белтрансгаз',
#  'бензин',
#  'бизнес',
#  'бизнесмен',
#  'биржа',
#  'ближний',
#  'блок',
#  'болгария',
#  'большой',
#  'борьба',
#  'будущее',
#  'бумага',
#  'бывший',
#  'быть',
#  'бюджет',
#  'вадим',
#  'вариант',
#  'ввести',
#  'вгтрк',
#  'вдвое',
#  'ведомство',
#  'вернуться',
#  'вести',
#  'весь',
#  'ветка',
#  'взять',
#  'видеть',
#  'виктор',
#  'владелец',
#  'владеть',
#  'владивосток',
#  'владимир',
#  'власть',
#  'влияние',
#  'вложить',
#  'вместе',
#  'вместо',
#  'внести',
#  'вновь',
#  'внутренний',
#  'возглавить',
#  'возглавлять',
#  'возможно',
#  'возможность',
#  'возможный',
#  'возникнуть',
#  'войти',
#  'вопрос',
#  'восток',
#  'восточный',
#  'впервые',
#  'впрочем',
#  'время',
#  'вряд',
#  'всего',
#  'вслед',
#  'встреча',
#  'втб',
#  'вторник',
#  'второе',
#  'входить',
#  'входящая',
#  'входящий',
#  'вхождение',
#  'вчера',
#  'выглядеть',
#  'выйти',
#  'выкуп',
#  'выкупить',
#  'выплата',
#  'выплатить',
#  'выполнить',
#  'выпуск',
#  'вырасти',
#  'выручка',
#  'высокий',
#  'выступать',
#  'выступить',
#  'выход',
#  'выше',
#  'вэб',
#  'газ',
#  'газа',
#  'газета',
#  'газификация',
#  'газовый',
#  'газоконденсатный',
#  'газопровод',
#  'газотранспортный',
#  'газпром',
#  'газпрома',
#  'газпромбанк',
#  'газпроммедиа',
#  'гендиректор',
#  'генеральный',
#  'геннадий',
#  'германия',
#  'глава',
#  'главный',
#  'говорить',
#  'говориться',
#  'говорят',
#  'год',
#  'годовой',
#  'город',
#  'госкомпания',
#  'господин',
#  'государственный',
#  'государство',
#  'готовиться',
#  'готовый',
#  'гпб',
#  'граница',
#  'греция',
#  'греческий',
#  'грозить',
#  'группа',
#  'грэс',
#  'гэх',
#  'давление',
#  'дальнейший',
#  'дальний',
#  'данные',
#  'дать',
#  'два',
#  'девять',
#  'действие',
#  'действующий',
#  'декабрь',
#  'дело',
#  'денис',
#  'день',
#  'деньга',
#  'департамент',
#  'дефицит',
#  'деятельность',
#  'дивиденд',
#  'директор',
#  'для',
#  'дмитрий',
#  'дмитрия',
#  'до',
#  'добавить',
#  'добиться',
#  'добывать',
#  'добыча',
#  'договор',
#  'договориться',
#  'договорённость',
#  'документ',
#  'долг',
#  'долгосрочный',
#  'должность',
#  'должный',
#  'доля',
#  'дополнительный',
#  'достигнуть',
#  'доступ',
#  'доход',
#  'дочерний',
#  'дочка',
#  'другой',
#  'дюков',
#  'евро',
#  'евробонд',
#  'еврокомиссия',
#  'еврооблигация',
#  'европа',
#  'европейский',
#  'евросоюз',
#  'единственный',
#  'ес',
#  'если',
#  'ждать',
#  'журналист',
#  'за',
#  'завершить',
#  'завод',
#  'задолженность',
#  'заимствование',
#  'заинтересовать',
#  'заключение',
#  'заключить',
#  'закон',
#  'законодательство',
#  'закрыть',
#  'закупать',
#  'закупка',
#  'заместитель',
#  'зампред',
#  'занимать',
#  'заниматься',
#  'занять',
#  'заняться',
#  'зао',
#  'западный',
#  'запас',
#  'заплатить',
#  'запуск',
#  'запустить',
#  'зарубежнефть',
#  'зарубежный',
#  'зарубежье',
#  'заседание',
#  'заявить',
#  'заявка',
#  'заявление',
#  'значительный',
#  'игорь',
#  'игрок',
#  'идея',
#  'идти',
#  'известно',
#  'издание',
#  'изз',
#  'изменение',
#  'изменить',
#  'именно',
#  'иметь',
#  'импортёр',
#  'инвестиционный',
#  'инвестиция',
#  'инвестор',
#  'инвестпрограмма',
#  'иностранный',
#  'интер',
#  'интервью',
#  'интерес',
#  'интерфакс',
#  'информация',
#  'инфраструктура',
#  'ирак',
#  'иран',
#  'иранский',
#  'иск',
#  'искать',
#  'исключать',
#  'использование',
#  'использовать',
#  'история',
#  'источник',
#  'италия',
#  'итальянский',
#  'итог',
#  'июль',
#  'июнь',
#  'как',
#  'канал',
#  'капитал',
#  'качество',
#  'квартал',
#  'киев',
#  'китай',
#  'китайский',
#  'клиент',
#  'ключевой',
#  'комиссия',
#  'комитет',
#  'коммерческий',
#  'компания',
#  'комплекс',
#  'конец',
#  'конкурент',
#  'конкуренция',
#  'конкурс',
#  'консорциум',
#  'контракт',
#  'контролировать',
#  'контроль',
#  'контрольный',
#  'конференция',
#  'конфликт',
#  'концерн',
#  'корпоративный',
#  'корпорация',
#  'который',
#  'кредит',
#  'кредитный',
#  'кризис',
#  'круг',
#  'крупный',
#  'крым',
#  'куб',
#  'кубометр',
#  'купить',
#  'лесин',
#  'лидер',
#  'линия',
#  'литва',
#  'лицензия',
#  'лицо',
#  'лишь',
#  'лукойл',
#  'льгота',
#  'май',
#  'максимальный',
#  'маленький',
#  'март',
#  'маршрут',
#  'материал',
#  'медведев',
#  'медиа',
#  'международный',
#  'межрегионгаз',
#  'меморандум',
#  'менее',
#  'мера',
#  'местный',
#  'место',
#  'месторождение',
#  'месяц',
#  'метр',
#  'мечело',
#  'миллер',
#  'миллиард',
#  'миллион',
#  'минимум',
#  'министерство',
#  'министр',
#  'миноритарий',
#  'минприрода',
#  'минфин',
#  'минэнерго',
#  'мир',
#  'мировой',
#  'михаил',
#  'мнение',
#  'мнпз',
#  'момент',
#  'монополист',
#  'монополия',
#  'мор',
#  'море',
#  'морской',
#  'москва',
#  'московский',
#  'мочь',
#  'мощность',
#  'мсфо',
#  'мы',
#  'на',
#  'надеяться',
#  'назад',
#  'назвать',
#  'назначить',
#  'называть',
#  'наиболее',
#  'найти',
#  'нак',
#  'налог',
#  'налоговый',
#  'намеренный',
#  'намерить',
#  'направить',
#  'направление',
#  'нарастить',
#  'наращивать',
#  'нарушение',
#  'настаивать',
#  'настоящее',
#  'нафтогаз',
#  'нафтогаза',
#  'находиться',
#  'национальный',
#  'начало',
#  'начальник',
#  'начать',
#  'начаться',
#  'начинать',
#  'наш',
#  'ндпить',
#  'небольшой',
#  'недавно',
#  'неделя',
#  'независимый',
#  'немецкий',
#  'необходимость',
#  'необходимый',
#  'несколько',
#  'несмотря',
#  'нет',
#  'нефтегазовый',
#  'нефтекомпания',
#  'нефтепродукт',
#  'нефти',
#  'нефть',
#  'нефтяник',
#  'нефтяной',
#  'ниже',
#  'низкий',
#  'никакой',
#  'николай',
#  'нитка',
#  'но',
#  'новак',
#  'новатэк',
#  'новое',
#  'новый',
#  'ноябрь',
#  'нпз',
#  'нтв',
#  'нужно',
#  'оао',
#  'обеспечить',
#  'обещать',
#  'область',
#  'облигация',
#  'обмен',
#  'образ',
#  'обратиться',
#  'обсуждать',
#  'обсуждаться',
#  'общий',
#  'объединить',
#  'объект',
#  'объесть',
#  'объявить',
#  'объяснять',
#  'объём',
#  'обязательство',
#  'огк2',
#  'один',
#  'однако',
#  'одобрить',
#  'ожидание',
#  'ожидать',
#  'оказаться',
#  'около',
#  'округа',
#  'октябрь',
#  'он',
#  'она',
#  'они',
#  'ооо',
#  'оператор',
#  'оплата',
#  'определить',
#  'опубликовать',
#  'организация',
#  'освоение',
#  'основной',
#  'основный',
#  'оставаться',
#  'остановить',
#  'остаться',
#  'отказ',
#  'отказаться',
#  'открытый',
#  'отметить',
#  'отмечать',
#  'отношение',
#  'отрасль',
#  'отчёт',
#  'отчётность',
#  'оферта',
#  'офис',
#  'официально',
#  'официальный',
#  'оценивать',
#  'оцениваться',
#  'оценка',
#  'очень',
#  'очередной',
#  'очередь',
#  'падение',
#  'пакет',
#  'пао',
#  'параметр',
#  'партнерство',
#  'партнёр',
#  'первое',
#  'переговоры',
#  'передавать',
#  'передать',
#  'пересмотр',
#  'период',
#  'перспектива',
#  'петербургский',
#  'план',
#  'планировать',
#  'планироваться',
#  'платить',
#  'платёж',
#  'по',
#  'повысить',
#  'повышение',
#  'погашение',
#  'подать',
#  'поддержать',
#  'поддержка',
#  'подземный',
#  'подконтрольный',
#  'подписание',
#  'подписать',
#  'подразделение',
#  'подрядчик',
#  'подтвердить',
#  'позволить',
#  'позиция',
#  'пойти',
#  'пока',
#  'показатель',
#  'покупатель',
#  'покупать',
#  'покупка',
#  'полагать',
#  'политика',
#  'политический',
#  'полностью',
#  'полный',
#  'половина',
#  'полугодие',
#  'получать',
#  'получение',
#  'получить',
#  'польза',
#  'польский',
#  'польша',
#  'понедельник',
#  'попрежний',
#  'попытка',
#  'пора',
#  'портфель',
#  'порядок',
#  'поскольку',
#  'после',
#  'последний',
#  'пост',
#  'поставить',
#  'поставка',
#  'поставлять',
#  'поставщик',
#  'построить',
#  'потеря',
#  'потерять',
#  'поток',
#  'потратить',
#  'потребитель',
#  'потребление',
#  'потребовать',
#  'поэтому',
#  'появиться',
#  'правило',
#  'правительство',
#  'правление',
#  'право',
#  'прайма',
#  'превысить',
#  'превышать',
#  'предварительный',
#  'предлагать',
#  'предложение',
#  'предложить',
#  'предоплата',
#  'предоставить',
#  'предполагать',
#  'предполагаться',
#  'предправление',
#  'предприятие',
#  'председатель',
#  'представитель',
#  'президент',
#  'премьера',
#  'премьерминистр',
#  'прессконференция',
#  'прессрелиз',
#  'прессслужба',
#  'претендент',
#  'претендовать',
#  'претензия',
#  'при',
#  'прибыль',
#  'прибыть',
#  'приватизация',
#  'привести',
#  'привлечение',
#  'привлечь',
#  'признать',
#  'прийтись',
#  'примерно',
#  'принадлежать',
#  'принадлежащий',
#  'принять',
#  'приобрести',
#  'приобретение',
#  'природный',
#  'приступить',
#  'присутствие',
#  'причина',
#  'проблема',
#  'проведение',
#  'проверка',
#  'провести',
#  'прогноз',
#  'программа',
#  'продавать',
#  'продажа',
#  'продать',
#  'продолжать',
#  'продолжить',
#  'проект',
#  'проектный',
#  'производитель',
#  'производство',
#  'произойти',
#  'пройти',
#  'просить',
#  'против',
#  'процесс',
#  'прошлое',
#  'прошлый',
#  'путин',
#  'пхг',
#  'пытаться',
#  'пятница',
#  'пять',
#  'работа',
#  'работать',
#  'радиостанция',
#  'раз',
#  'разбирательство',
#  'разведка',
#  'развитие',
#  'размер',
#  'разместить',
#  'размещение',
#  'разрабатывать',
#  'разработка',
#  'разрешение',
#  'рамка',
#  'ранее',
#  'ранний',
#  'рао',
#  'рассказать',
#  'расследование',
#  'рассматривать',
#  'рассмотреть',
#  'рассчитывать',
#  'расти',
#  'расход',
#  'расчёт',
#  'расширение',
#  'реализация',
#  'реальный',
#  'регион',
#  'регулятор',
#  'резерв',
#  'резкий',
#  'резко',
#  'результат',
#  'рейтинг',
#  'реклама',
#  'ремонт',
#  'республика',
#  'ресурс',
#  'речь',
#  'решение',
#  'решить',
#  'риска',
#  'роснефтегаз',
#  'роснефти',
#  'роснефть',
#  'российский',
#  'россия',
#  'рост',
#  'ростелеком',
#  'рсб',
#  'рубль',
#  'руководитель',
#  'руководство',
#  'рф',
#  'рынок',
#  'рыночный',
#  'ряд',
#  'сайт',
#  'сам',
#  'самый',
#  'санктпетербург',
#  'санкция',
#  'сахалин',
#  'сбербанк',
#  'сбыт',
#  'сбытовый',
#  'свой',
#  'связать',
#  'связь',
#  'сделать',
#  'сделка',
#  'северный',
#  'северэнергия',
#  'сегодня',
#  'сей',
#  'сейчас',
#  'сентябрь',
#  'сербия',
#  'сербский',
#  'сергей',
#  'середина',
#  'серьёзный',
#  'сеть',
#  'сечин',
#  'сжидить',
#  'сибирь',
#  'сила',
#  'система',
#  'ситуация',
#  'сказать',
#  'скидка',
#  'скорее',
#  'скорректировать',
#  'сланцевый',
#  'следовать',
#  'следующий',
#  'словакия',
#  'слово',
#  'служба',
#  'случай',
#  'смочь',
#  'снижение',
#  'снизить',
#  'снизиться',
#  'собеседник',
#  'собираться',
#  'собрание',
#  'собственный',
#  'совет',
#  'совещание',
#  'совладелец',
#  'совместный',
#  'согласиться',
#  'согласовать',
#  'соглашение',
#  'создание',
#  'создать',
#  'сократить',
#  'сократиться',
#  'сокращение',
#  'сомневаться',
#  'сообщать',
#  'сообщаться',
#  'сообщение',
#  'сообщить',
#  'соответствие',
#  'соответствующий',
#  'состав',
#  'составить',
#  'составлять',
#  'состояться',
#  'сотрудник',
#  'сотрудничество',
#  'сохранение',
#  'сохранить',
#  'сп',
#  'спг',
#  'список',
#  'спортивный',
#  'спорый',
#  'способ',
#  'спотовой',
#  'спрос',
#  'сравнение',
#  'среда',
#  'среди',
#  'средний',
#  'средство',
#  'срок',
#  'ссылка',
#  'ставка',
#  'стандарт',
#  'станция',
#  'стать',
#  'стоимость',
#  'стокгольмский',
#  'столкнуться',
#  'сторона',
#  'страна',
#  'стратегический',
#  'стратегия',
#  'строительство',
#  'строить',
#  'стройтрансгаз',
#  'структура',
#  'суд',
#  'судебный',
#  'сумма',
#  'сутки',
#  'существенный',
#  'сфера',
#  'схема',
#  'считать',
#  'счёт',
#  'сша',
#  'сырьё',
#  'так',
#  'также',
#  'такой',
#  'тариф',
#  'тасс',
#  'тв',
#  'текущий',
#  'телеканал',
#  'тем',
#  'тендер',
#  'теперь',
#  'терминал',
#  'территория',
#  'технология',
#  'течение',
#  'тимченко',
#  'тнквр',
#  'тнт',
#  'том',
#  'тонна',
#  'топливо',
#  'топменеджер',
#  'торг',
#  'тот',
#  'транзит',
#  'транзитный',
#  'транснефть',
#  'транспортировка',
#  'требование',
#  'требовать',
#  'треть',
#  'третье',
#  'три',
#  'триллион',
#  'труба',
#  'трубопровод',
#  'трубопроводный',
#  'турецкий',
#  'турция',
#  'тысяча',
#  'убыток',
#  'увеличение',
#  'увеличивать',
#  'увеличить',
#  'увеличиться',
#  'уверять',
#  'углеводород',
#  'угольный',
#  'угроза',
#  'удаться',
#  'украина',
#  'украинский',
#  'украины',
#  'упасть',
#  'управление',
#  'управлять',
#  'уровень',
#  'условие',
#  'услуга',
#  'установка',
#  'утвердить',
#  'утверждать',
#  'уточнить',
#  'участвовать',
#  'участие',
#  'участник',
#  'участок',
#  'учёт',
#  'фактически',
#  'фас',
#  'февраль',
#  'федеральный',
#  'финансирование',
#  'финансовый',
#  'фон',
#  'фонд',
#  'формула',
#  'форум',
#  'французский',
#  'фёдоров',
#  'ход',
#  'холдинг',
#  'хотеть',
#  'хотя',
#  'хранилище',
#  'целое',
#  'цель',
#  'цена',
#  'центр',
#  'центральный',
#  'частное',
#  'частность',
#  'часть',
#  'четверг',
#  'четыре',
#  'чиновник',
#  'число',
#  'чистый',
#  'член',
#  'что',
#  'шельф',
#  'шельфовый',
#  'штокман',
#  'штокмановский',
#  'штраф',
#  'экономика',
#  'экономический',
#  'эксперт',
#  'экспорт',
#  'экспортный',
#  'электростанция',
#  'эмитент',
#  'энергетика',
#  'энергетический',
#  'энергокомпания',
#  'энергохолдинг',
#  'это',
#  'этот',
#  'эхо',
#  'южный',
#  'являться',
#  'яковлев',
#  'ямал',
#  'январь']

# %%
lda = lda(n_topics=20, max_iter=50, learning_method='batch', random_state=1337)
lda.fit(transformed_dataset)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='batch', learning_offset=10.0,
#              max_doc_update_iter=100, max_iter=50, mean_change_tol=0.001,
#              n_jobs=1, n_topics=20, perp_tol=0.1, random_state=1337,
#              topic_word_prior=None, total_samples=1000000.0, verbose=0)

# %%
def print_top_words(model, feature_names, n_top_words):
    res = ''
    for topic_idx, topic in enumerate(model.components_):
        res += ' '.join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]])
        res += ' '
    return res

# %%
n_top_words = 20
lda
res = print_top_words(lda, tf_feature_names, n_top_words)
themes = ' '.join(list(set(res.split())))
print(' '.join(list(set(res.split()))))
print(len(' '.join(list(set(res.split()))).split()))
# Out:
# дивиденд вопрос производитель фонд производство украина создание составить владимир тнквр миллион прибыль как бизнесмен медиа отношение новатэк льгота идея газпроммедиа история вэб газпрома литва поставка рао совет договор компания пхг геннадий путин свой директор развитие подписать интерфакс завод газа гендиректор чистый акционер nord stream сообщать бензин совместный гэх монополия доля комитет федеральный банк экспорт бывший тендер нпз интер вырасти пакет lietuvos закупка национальный снижение новый спг александр общий антимонопольный европейский принять годовой метр правительство втб немецкий также построить 2013 проект участок контрольный грэс добыча рынок лукойл станция капитал миллер eni холдинг другой налог предлагать south сообщение генеральный москва два поток иск участие gazprom заявить итог мощность крупный налоговый московский источник алексей россия труба рейтинг сторона продажа он строительство привлечь заявка готовый топливо евро ссылка год на подземный тот газовый продать собрание считать долг концерн предприятие суд газпром месторождение время хранилище газопровод группа телеканал 2014 правление нафтогаза состав стройтрансгаз президент доступ арбитражный газ украинский планировать роснефть турция сербия киев арбитраж структура выплата южный председатель средство акция рубль получить shell входить квартал изз тв говориться турецкий канал нефтяной зао 2011 ндпить актив один служба рост отчёт сделка dujos решение подать но энергохолдинг лицензия фас независимый сообщить ремонт объём мочь сумма шельф роснефти потребитель который минфин журналист сбербанк выйти куб нтв разработка тнт кредит цена агентство купить 24 найти мнение это нефть огк2 очередь кубометр европа тимченко одобрить нафтогаз транзит по реклама соглашение переговоры nis контракт газпромбанк российский миллиард сказать подконтрольный 15 банка оао пока сеть стать реализация
# 245

# %%
df['text_lda'] = df['text']
for i in tqdm(range(len(df['text']))):
    sent = df['text'][i]
    res = []
    for word in sent.split():
        if word in themes:
            res.append(word)
    df['text_lda'][i] = ' '.join(res)
# Out:
# 100%|██████████| 1159/1159 [12:00:25<00:00, 37.30s/it]

# %%
df.head()
# Out:
#                   Date                                               text  \
# 0  2017-11-09 00:00:00  компания рассчитывать решение газовый спор укр...
# 1  2017-11-08 00:00:00  как предполагать “ъ” «газпром» воспользоваться...
# 2  2017-11-01 00:00:00  новый редакция американский санкция ставить уг...
# 3  2017-10-30 00:00:00  как стать известно “ъ” известный рынок рискмен...
# 4  2017-10-23 00:00:00  новатэк который пять год собираться запустить ...
#
#                                        text_original  target  \
# 0  Компания рассчитывает на решение по газовому с...       0
# 1   Как и предполагал “Ъ”, «Газпром», воспользова...       1
# 2   Новая редакция американских санкций ставит по...       1
# 3   Как стало известно “Ъ”, известный на рынке ри...       1
# 4   НОВАТЭК, который через пять лет собирается за...       1
#
#                                           text_nouns  \
# 0  компания решение украина конец декабрь решение...
# 1  жалоба партнёр налогообложение проект рф сниже...
# 2  редакция санкция угроза проект компания гражда...
# 3  рынок рискменеджер itспециалист вадим кулик ра...
# 4  новатэк год камчатка терминал проблема обеспеч...
#
#                                     text_nouns_verbs  \
# 0  компания решение украина конец декабрь решение...
# 1  жалоба партнёр налогообложение проект рф сниже...
# 2  редакция санкция угроза проект компания гражда...
# 3  рынок рискменеджер itспециалист вадим кулик ра...
# 4  новатэк год камчатка терминал проблема обеспеч...
#
#                                             text_lda
# 0  компания решение газовый спор украина решение ...
# 1  как проект рф снижение налог добыча ндпить сво...
# 2  новый ставить нефтяной проект российский компа...
# 3  как стать рынок газпромбанк о правление год вт...
# 4  новатэк который год крупный спг готовый газ по...

# %%
df_train, df_test = df[df['Date'] < datetime(2016, 1, 1)], df[df['Date'] >= datetime(2016, 1, 1)]
print('train size %d, test size %d' % (df_train.shape[0], df_test.shape[0]))
# Out:
# train size 901, test size 258

# %%
# build binary feature matrix from BoW model
vec = TfidfVectorizer(lowercase=True, analyzer='word', ngram_range=(2,4), norm=None, use_idf=False, binary=True)
X = vec.fit_transform(df_train.text_lda)
print('feature matrix shape', X.shape)

# encode class labels
label_enc = LabelEncoder().fit(df_train.target)
y_train = label_enc.transform(df_train.target)

grid = GridSearchCV(MultinomialNB(), # our model 
                    param_grid={'alpha': np.linspace(-1.0, 2.0, 31)})
 
grid.fit(X, y_train)
print('best params', grid.best_params_)
print('best estimator', grid.best_score_)
model = grid.best_estimator_


# fit our prediction model

model.fit(X, y_train)
print('train f1_score', metrics.f1_score(y_train, model.predict(X)))
print('train accuracy', metrics.accuracy_score(y_train, model.predict(X)))

# perfomance on test dataset
X_test = vec.transform(df_test.text_lda)
y_pred = model.predict(X_test)
y_test = label_enc.transform(df_test.target)
print('test f1_score', metrics.f1_score(y_test, model.predict(X_test)))
print('test accuracy', metrics.accuracy_score(y_test, model.predict(X_test)))
# Out:
# feature matrix shape (901, 56930)
# best params {'alpha': 0.10000000000000009}
# best estimator 0.5427302996670367
# train f1_score 1.0
# train accuracy 1.0
# test f1_score 0.465648854961832
# test accuracy 0.4573643410852713

# %% [markdown]
# ### Качество улучшить не удалось, нам кажется из-за того, что очень маленький датасет (да и было оно не намного лучше рандома скажем честно)

# %% [markdown]
# ## Сдача домашнего задания
#
# Дедлайн сдачи домашнего задания:  23:59 22.03.2018. Каждый день просрочки дедлайна штрафуется -1 баллом.
#
# Результаты домашнего задания должны быть оформлены в виде отчета в jupyter notebook.
# Нормальный отчёт должен включать в себя:
# * Краткую постановку задачи и формулировку задания
# * Описание минимума необходимой теории и/или описание используемых инструментов
# * Подробный пошаговый рассказ о проделанной работе
# * **Аккуратно** оформленные результаты
# * Подробные и внятные ответы на все заданные вопросы
# * Внятные выводы – не стоит относится к домашнему заданию как к последовательности сугубо технических шагов, а стоит относится скорее как к небольшому практическому исследованию, у которого есть своя цель и свое назначение.
#
# Задание выполняется в группе до трех человек. Не забудьте перечислить фамилии всех, кто работал над домашнем задании, в jupyter notebook.
#
# В случае использования какого-либо строннего источника информации обязательно дайте на него ссылку (поскольку другие тоже могут на него наткнуться). Плагиат наказывается нулём баллов за задание и предвзятым отношением в будущем.
#
#
# При возникновении проблем с выполнением задания обращайтесь с вопросами к преподавателю по семинарским занятиям в вашей группе или у учебным ассистентам.
#
# Учебный ассистент по ДЗ 2: Таисия Глушкова (email: glushkovato@gmail.com, telegram: @glushkovato).
#
#
# Небрежное оформление отчета существенно отразится на итоговой оценке. Весь код из отчёта должен быть воспроизводимым, если для этого нужны какие-то дополнительные действия, установленные модули и т.п. — всё это должно быть прописано в отчете в явном виде.
#
# Сдача отчетов осуществляется через систему AnyTask.
